# %%
from pymixin.mixin_bot_api import MixinBotApi
from pymixin.mixin_api import MixinApi
api = MixinApi('http://127.0.0.1:8001')

# %%
config = {
    "client_secret": "db5b5fa92861b06c5a3f6478c703e107b24a438a6eac0c3bfb08c28d1e640cf5",
    "pin": "486485",
    "client_id": "e0148fc6-0e10-470e-8127-166e0829c839",
    "session_id": "21ea43ad-1f6a-4c60-9370-b109b1c798d9",
    "pin_token": "LIOBdgJJdYoRGDJIODWom7imbI7dv/srON+rc7qTeAuHhf8xlykzQ30WZ8FVGEOgV42TISde78j6KubSrGPijqEWueekFFN/1fPk7Kxa939nV/Ywzfq3jWs2whcZV1Kk4nsxon0m3FV7jJFBEG7+XjBxv1xKkfgPLXMABpuTLxs=",
    "private_key": "-----BEGIN RSA PRIVATE KEY-----\r\\r\n-----END RSA PRIVATE KEY-----\r\n"
}
bot = MixinBotApi(config)

# %%
eos_asset_id = api.get_eos_asset_id('eosio.token', 'EOS')

# %%
eos_asset_id
# Out:
# '6ac4cbffda9952e7f0d924e4cfb6beb29d21854ac00bfbf749f086302d0f7e5d'

# %%
from eth_account import Account

# %%
a = Account.create()
a.privateKey.hex(), a.address
# Out:
# ('0xd121c26906a9a2bc3a5ea218dc738da262ceedcaa173cd812aee898d3d4fe095',
#  '0xdd4d5bF43348101A353d5f11d813E1fd2bEDDb3D')

# %%
eos_asset_id = '4d8c508b-91c5-375b-92b0-ee702ed2dac5'
eth_asset_id = '6cfe566e-4aad-470b-8c9a-2fd35b49c68d'
await bot.create_address(eos_asset_id, account_name='0x414719A08521B73D87E9850ed891805cE862226B', account_tag='helloworld')
# Out:
# {'data': {'type': 'address',
#   'address_id': '2ffce5cc-ab65-4424-b522-1f2904c71274',
#   'asset_id': '4d8c508b-91c5-375b-92b0-ee702ed2dac5',
#   'destination': '0x414719A08521B73D87E9850ed891805cE862226B',
#   'tag': 'helloworld',
#   'label': 'helloworld',
#   'fee': '0.01',
#   'reserve': '0',
#   'dust': '0.0001',
#   'updated_at': '2021-03-22T15:45:56.980431767Z'}}

# %%
eos_asset_id = '4d8c508b-91c5-375b-92b0-ee702ed2dac5'
#eth_asset_id = '6cfe566e-4aad-470b-8c9a-2fd35b49c68d'
await bot.create_address(eth_asset_id, account_name='0xdd4d5bF43348101A353d5f11d813E1fd2bEDDb3D', account_tag='helloworld2')
# Out:
# {'error': {'status': 500, 'code': 500, 'description': 'Internal Server Error'}}

# %%
await bot.get_my_profile('')
# Out:
# {'error': {'status': 202,
#   'code': 401,
#   'description': 'Unauthorized, maybe invalid token.'}}

# %%
user_id = 'e07c06fa-084c-4ce1-b14a-66a9cb147b9e'
await bot.get_ghost_keys(user_id)
# Out:
# {'data': {'type': 'ghost_key',
#   'mask': '75c754d825510d24151d0d58d76c2385c60635385bd5d2daedeeb8d63435be2a',
#   'keys': ['dbcc98b5cc9299847a56385dd6459b5b60a030ff1266eb876460a682d9d82c35']}}

# %%
await bot.get_multi_signs()
# Out:
# {'data': []}

# %%
await bot.get_users_info(user_id, '')
# Out:
# {'error': {'status': 202,
#   'code': 401,
#   'description': 'Unauthorized, maybe invalid token.'}}

# %%
cnb_asset_id = 'b9f49cf777dc4d03bc54cd1367eebca319f8603ea1ce18910d09e2c540c630d8'
cnb_asset_id = 'c6d0c728-2624-429b-8e0d-d9d19b6592fa'

# %%
eos_asset_id = '6cfe566e-4aad-470b-8c9a-2fd35b49c68d'
await bot.get_asset(eos_asset_id)
# Out:
# {'data': {'type': 'asset',
#   'asset_id': '6cfe566e-4aad-470b-8c9a-2fd35b49c68d',
#   'chain_id': '6cfe566e-4aad-470b-8c9a-2fd35b49c68d',
#   'symbol': 'EOS',
#   'name': 'EOS',
#   'icon_url': 'https://mixin-images.zeromesh.net/a5dtG-IAg2IO0Zm4HxqJoQjfz-5nf1HWZ0teCyOnReMd3pmB8oEdSAXWvFHt2AJkJj5YgfyceTACjGmXnI-VyRo=s128',
#   'balance': '0',
#   'deposit_entries': [{'destination': 'eoswithmixin',
#     'tag': '62e9871d0340fdd225f2364b2e0dc20e'}],
#   'destination': 'eoswithmixin',
#   'tag': '62e9871d0340fdd225f2364b2e0dc20e',
#   'price_btc': '0.00007481',
#   'price_usd': '4.28',
#   'change_btc': '0.024093086926762493',
#   'change_usd': '0.01904761904761905',
#   'asset_key': 'eosio.token:EOS',
#   'mixin_id': '6ac4cbffda9952e7f0d924e4cfb6beb29d21854ac00bfbf749f086302d0f7e5d',
#   'reserve': '0',
#   'confirmations': 64,
#   'capitalization': 0,
#   'liquidity': '0'}}

# %%
xin_asset_id = 'c94ac88f-4671-3976-b60a-09064f1811e8'
await bot.get_asset(xin_asset_id)
# Out:
# {'data': {'type': 'asset',
#   'asset_id': '6cfe566e-4aad-470b-8c9a-2fd35b49c68d',
#   'chain_id': '6cfe566e-4aad-470b-8c9a-2fd35b49c68d',
#   'symbol': 'EOS',
#   'name': 'EOS',
#   'icon_url': 'https://mixin-images.zeromesh.net/a5dtG-IAg2IO0Zm4HxqJoQjfz-5nf1HWZ0teCyOnReMd3pmB8oEdSAXWvFHt2AJkJj5YgfyceTACjGmXnI-VyRo=s128',
#   'balance': '0',
#   'deposit_entries': [{'destination': 'eoswithmixin',
#     'tag': '62e9871d0340fdd225f2364b2e0dc20e'}],
#   'destination': 'eoswithmixin',
#   'tag': '62e9871d0340fdd225f2364b2e0dc20e',
#   'price_btc': '0.00007477',
#   'price_usd': '4.28',
#   'change_btc': '0.018942491142000546',
#   'change_usd': '0.014218009478672985',
#   'asset_key': 'eosio.token:EOS',
#   'mixin_id': '6ac4cbffda9952e7f0d924e4cfb6beb29d21854ac00bfbf749f086302d0f7e5d',
#   'reserve': '0',
#   'confirmations': 64,
#   'capitalization': 0,
#   'liquidity': '0'}}

# %%
await bot.top_assets()
# Out:
# {'data': {'assets': [{'amount': '7902.47987961',
#     'asset_id': 'c6d0c728-2624-429b-8e0d-d9d19b6592fa',
#     'icon_url': 'https://mixin-images.zeromesh.net/HvYGJsV5TGeZ-X9Ek3FEQohQZ3fE9LBEBGcOcn4c4BNHovP4fW4YB97Dg5LcXoQ1hUjMEgjbl1DPlKg1TW7kK6XP=s128',
#     'symbol': 'BTC',
#     'type': 'asset'},
#    {'amount': '532364.85099311',
#     'asset_id': 'c94ac88f-4671-3976-b60a-09064f1811e8',
#     'icon_url': 'https://mixin-images.zeromesh.net/UasWtBZO0TZyLTLCFQjvE_UYekjC7eHCuT_9_52ZpzmCC-X-NPioVegng7Hfx0XmIUavZgz5UL-HIgPCBECc-Ws=s128',
#     'symbol': 'XIN',
#     'type': 'asset'},
#    {'amount': '199898935.7419738',
#     'asset_id': 'f5ef6b5d-cc5a-3d90-b2c0-a2fd386e7a3c',
#     'icon_url': 'https://mixin-images.zeromesh.net/ml7tg1ZGrQt6IJSvEusWFfthosOB98GWN7r4EkmgSP8tbJHxK7OWki9zfZFFDCDOJE0nlLBR6dc4nbUguXE3Bg4=s128',
#     'symbol': 'BOX',
#     'type': 'asset'},
#    {'amount': '64975.59382785',
#     'asset_id': '43d61dcd-e413-450d-80b8-101d5e903357',
# ...

# %%
await bot.snapshots(0, cnb_asset_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-949c521ea82b> in async-def-wrapper()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/mixin/mixin_bot_api.py in snapshots(self, offset, asset_id, order, limit)
#     510         }
#     511
# --> 512         return await self.__genGetRequest('/network/snapshots', body)
#     513
#     514     async def snapshot(self, snapshot_id):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/mixin/mixin_bot_api.py in __genGetRequest(self, path, auth_token)
#     139             r = await self.client.get(url)
#     140         else:
# --> 141             r = await self.client.get(url, headers={"Authorization": "Bearer " + auth_token})
#     142
#     143         result_obj = r.json()
#
# TypeError: can only concatenate str (not "dict") to str
